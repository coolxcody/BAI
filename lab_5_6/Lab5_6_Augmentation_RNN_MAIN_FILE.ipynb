# %% [markdown]
# # Lab 5 + 6 — Augmentacja danych dla CNN + Rekurencyjne Sieci Neuronowe
#
# **Wybrane Zagadnienia / Zaawansowane Metody Sztucznej Inteligencji · II stopień**
#
# ---
#
# ## Co zrobimy na tym podwójnym labie
#
# **Część 1 — Lab 5: Augmentacja danych dla CNN**
# 1. **Dlaczego augmentacja?** — overfitting i mały dataset
# 2. **Galeria technik** — geometria, kolor, maskowanie, Mixup/CutMix
# 3. **ImageDataGenerator** — "on-the-fly" augmentacja w TensorFlow
# 4. **CIFAR-10 baseline** — CNN bez augmentacji (overfittuje)
# 5. **CIFAR-10 z augmentacją** — porównanie
# 6. **Hyperparameter tuning** — Random Search + KFold dla zakresów augmentacji
#
# **Część 2 — Lab 6: RNN, LSTM, GRU**
# 1. **Po co RNN?** — dane sekwencyjne vs siatkowe (CNN)
# 2. **Architektura RNN** — pętla rekurencyjna, stan ukryty, BPTT
# 3. **Typy struktur** — one-to-many, many-to-one, seq2seq
# 4. **Vanishing/exploding gradient** — problem i rozwiązania
# 5. **LSTM** — bramki forget/input/output
# 6. **GRU** — uproszczona alternatywa
# 7. **DEMO LSTM** — predykcja sinusoidy z szumem (zadanie z PDF)
#
# **Część 3 — Zadania samodzielne**
# - Lab 5: CIFAR-10 z optymalizacją parametrów augmentacji
# - Lab 6: PM-10 prediction dla Krakowa (Złoty Róg)

# %% [markdown]
# ---
#
# ## 0. Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

tf.random.set_seed(42)
np.random.seed(42)

print(f"TensorFlow: {tf.__version__}")
print(f"GPU: {len(tf.config.list_physical_devices('GPU')) > 0}")
print("\nTip: na CPU CIFAR uczy sie ~2-3 min, LSTM ~30s. Na GPU 10x szybciej.")
# Out:
# TensorFlow: 2.16.2
# GPU: True
#
# Tip: na CPU CIFAR uczy sie ~2-3 min, LSTM ~30s. Na GPU 10x szybciej.

# %% [markdown]
# ---
#
# # CZĘŚĆ 1 — Lab 5: Augmentacja danych dla CNN
#
# ## 1.1. Dlaczego augmentacja?
#
# **Problem:** CNN potrzebuje **dużo** danych żeby się dobrze generalizować. Jeśli masz 1000 zdjęć kota i 1000 psa — model zapamiętuje **te konkretne** zdjęcia (overfitting), a nie *czym jest kot*.
#
# **Rozwiązanie:** sztucznie zwiększamy dataset przez **transformacje** istniejących zdjęć. Kot obrócony o 10° to nadal kot. Kot z większą jasnością to nadal kot. Sieć uczy się **inwariantności**.
#
# ### Trzy główne korzyści
#
# | Korzyść | Dlaczego |
# |---------|----------|
# | **Zapobieganie overfittingowi** | Sieć nie widzi nigdy dwa razy tego samego zdjęcia |
# | **Symulowanie rzeczywistych wariacji** | W realnym świecie kot może być pod różnym kątem |
# | **Zwiększanie datasetu "za darmo"** | Bez zbierania nowych danych |
#
# ### Dwie praktyki
#
# - **On-the-fly** — augmentacja w czasie treningu, każda epoka = nowe wersje (popularne, oszczędza dysk)
# - **Pre-processing** — generujemy zmienione zdjęcia z wyprzedzeniem i zapisujemy (rzadziej)

# %% [markdown]
# ## 1.2. Galeria technik augmentacji
#
# Pokażemy każdą technikę na jednym obrazku z MNIST/CIFAR, żeby było widać efekt.

# %%
# Wczytaj CIFAR-10 (10 klas obrazow 32x32 RGB)
(x_cifar_train, y_cifar_train), (x_cifar_test, y_cifar_test) = keras.datasets.cifar10.load_data()

class_names = ['samolot', 'auto', 'ptak', 'kot', 'jelen',
               'pies', 'zaba', 'kon', 'statek', 'ciezarowka']

print(f"x_cifar_train: {x_cifar_train.shape}  (50k obrazow 32x32x3)")
print(f"y_cifar_train: {y_cifar_train.shape}")

# Wybierzmy jeden obrazek -- np. psa
idx = np.where(y_cifar_train.flatten() == 5)[0][0]  # pies
obraz = x_cifar_train[idx]
print(f"\nObraz testowy: {class_names[y_cifar_train[idx][0]]}")

plt.figure(figsize=(3, 3))
plt.imshow(obraz)
plt.title(f"Oryginal -- {class_names[y_cifar_train[idx][0]]}")
plt.axis('off')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# x_cifar_train: (50000, 32, 32, 3)  (50k obrazow 32x32x3)
# y_cifar_train: (50000, 1)
#
# Obraz testowy: pies

# %% [markdown]
# ### Grupa A: Transformacje geometryczne
#
# **Obrót, odbicie, skalowanie, przesunięcie, ścinanie.** Zmieniają **pozycję pikseli** ale nie ich wartości.

# %%
# Galeria transformacji geometrycznych
from tensorflow.keras.preprocessing.image import ImageDataGenerator

obraz_batch = np.expand_dims(obraz, 0)  # (1, 32, 32, 3) -- IDG wymaga batcha

transforms_geo = {
    "Obrot (+/- 30deg)":   ImageDataGenerator(rotation_range=30),
    "Odbicie poziome":     ImageDataGenerator(horizontal_flip=True),
    "Skalowanie (0.7-1.3)":ImageDataGenerator(zoom_range=0.3),
    "Przesuniecie poziome":ImageDataGenerator(width_shift_range=0.2),
    "Przesuniecie pionowe":ImageDataGenerator(height_shift_range=0.2),
    "Scinanie (shear)":    ImageDataGenerator(shear_range=20),
}

fig, axes = plt.subplots(2, 6, figsize=(15, 5))
for col, (name, gen) in enumerate(transforms_geo.items()):
    axes[0, col].imshow(obraz)
    axes[0, col].set_title("oryginal", fontsize=9)
    axes[0, col].axis('off')
    aug_iter = gen.flow(obraz_batch, batch_size=1, seed=col)
    aug = next(aug_iter)[0].astype('uint8')
    axes[1, col].imshow(aug)
    axes[1, col].set_title(name, fontsize=9)
    axes[1, col].axis('off')
plt.suptitle("Transformacje geometryczne", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Grupa B: Modyfikacje intensywności i kolorów
#
# **Jasność, kontrast, nasycenie, szum.** Zmieniają **wartości pikseli** ale nie ich pozycje.

# %%
# Reczne implementacje (IDG nie ma wszystkich tych opcji)
from tensorflow.image import (adjust_brightness, adjust_contrast,
                              adjust_saturation)

obraz_f = obraz.astype('float32') / 255.0

transforms_color = {
    "Jasniejszy (+0.3)": adjust_brightness(obraz_f, 0.3).numpy(),
    "Ciemniejszy (-0.3)": adjust_brightness(obraz_f, -0.3).numpy(),
    "Kontrast x2":        adjust_contrast(obraz_f, 2.0).numpy(),
    "Nasycenie x2":       adjust_saturation(obraz_f, 2.0).numpy(),
    "Szum gaussa":        np.clip(obraz_f + np.random.normal(0, 0.1, obraz_f.shape), 0, 1),
}

fig, axes = plt.subplots(1, 6, figsize=(15, 3))
axes[0].imshow(obraz)
axes[0].set_title("oryginal", fontsize=10)
axes[0].axis('off')
for col, (name, aug) in enumerate(transforms_color.items(), 1):
    axes[col].imshow(np.clip(aug, 0, 1))
    axes[col].set_title(name, fontsize=10)
    axes[col].axis('off')
plt.suptitle("Modyfikacje intensywnosci i kolorow", fontsize=14, y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Grupa C: Cięcie i maskowanie (Random Erasing, Mixup, CutMix)
#
# **Zaawansowane techniki 2020+.** Wymuszają na sieci, żeby nie patrzyła tylko na jeden fragment obrazu.

# %%
def random_erasing(img, max_size=0.3):
    """Losowe wymazanie kawalka obrazu."""
    img = img.copy()
    h, w = img.shape[:2]
    sh = int(h * np.random.uniform(0.1, max_size))
    sw = int(w * np.random.uniform(0.1, max_size))
    y = np.random.randint(0, h - sh)
    x = np.random.randint(0, w - sw)
    img[y:y+sh, x:x+sw] = np.random.randint(0, 255, (sh, sw, 3))
    return img

def mixup(img1, img2, alpha=0.5):
    """Liniowa interpolacja dwoch obrazow."""
    return (alpha * img1 + (1 - alpha) * img2).astype('uint8')

def cutmix(img1, img2, frac=0.4):
    """Wycinamy kawalek img2 i wklejamy do img1."""
    img = img1.copy()
    h, w = img.shape[:2]
    sh = int(h * frac); sw = int(w * frac)
    y = np.random.randint(0, h - sh); x = np.random.randint(0, w - sw)
    img[y:y+sh, x:x+sw] = img2[y:y+sh, x:x+sw]
    return img

# Drugi obraz -- kot
idx2 = np.where(y_cifar_train.flatten() == 3)[0][0]
obraz2 = x_cifar_train[idx2]

fig, axes = plt.subplots(1, 4, figsize=(12, 3))
axes[0].imshow(obraz); axes[0].set_title("oryginal (pies)"); axes[0].axis('off')
axes[1].imshow(random_erasing(obraz)); axes[1].set_title("Random Erasing"); axes[1].axis('off')
axes[2].imshow(mixup(obraz, obraz2)); axes[2].set_title("Mixup (pies+kot 50:50)"); axes[2].axis('off')
axes[3].imshow(cutmix(obraz, obraz2)); axes[3].set_title("CutMix (pies+kot patch)"); axes[3].axis('off')
plt.suptitle("Cięcie i maskowanie", fontsize=14, y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 1.3. ImageDataGenerator — augmentacja w treningu
#
# `ImageDataGenerator` to klasa Keras, która **w czasie rzeczywistym** generuje zmienione wersje obrazów dla każdej epoki.
#
# **Kluczowy zysk:** sieć w 100 epok widzi **100 różnych** wersji każdego obrazu. Bez augmentacji widzi ten sam 100 razy.

# %%
# Demonstracja: 12 wersji tego samego psa z augmentacja "all-in"
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.15,
    horizontal_flip=True,
    brightness_range=(0.7, 1.3),
)

aug_iter = datagen.flow(np.expand_dims(obraz, 0), batch_size=1)

fig, axes = plt.subplots(2, 6, figsize=(14, 5))
for ax in axes.flat:
    aug = next(aug_iter)[0].astype('uint8')
    ax.imshow(aug)
    ax.axis('off')
plt.suptitle("12 wersji tego samego psa przez ImageDataGenerator", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

print("Kazda komorka to ten sam piksel, ale po roznych transformacjach.")
print("To dziala na BIEZACO podczas .fit() -- nie zapisujemy zmodyfikowanych obrazow.")
# Out:
# Kazda komorka to ten sam piksel, ale po roznych transformacjach.
# To dziala na BIEZACO podczas .fit() -- nie zapisujemy zmodyfikowanych obrazow.

# %% [markdown]
# ---
#
# ## 1.4. Baseline CNN — CIFAR-10 BEZ augmentacji
#
# Najpierw trenujemy **bez** augmentacji. Zobaczymy wyraźny overfitting.
#
# **Setup zadania (z PDF):**
# - Ograniczamy CIFAR-10 do **4 klas i 2000 zdjęć** (szybsza optymalizacja)
# - Normalizacja (mean/std)
# - One-hot encoding etykiet

# %%
# Ograniczamy do 4 klas i 2000 zdjec
KLASY = [3, 5, 6, 7]  # kot, pies, zaba, kon
N_CLASSES = len(KLASY)
N_TRAIN = 2000

# Filtruj train
mask_train = np.isin(y_cifar_train.flatten(), KLASY)
x_tr = x_cifar_train[mask_train][:N_TRAIN]
y_tr = y_cifar_train[mask_train][:N_TRAIN]

# Filtruj test
mask_test = np.isin(y_cifar_test.flatten(), KLASY)
x_te = x_cifar_test[mask_test]
y_te = y_cifar_test[mask_test]

# Przemapuj etykiety na 0..3
label_map = {orig: new for new, orig in enumerate(KLASY)}
y_tr = np.vectorize(label_map.get)(y_tr.flatten())
y_te = np.vectorize(label_map.get)(y_te.flatten())

# Normalizacja (mean/std) -- standard ML practice
x_tr_f = x_tr.astype('float32')
x_te_f = x_te.astype('float32')
mean = x_tr_f.mean(axis=(0, 1, 2))
std = x_tr_f.std(axis=(0, 1, 2))
x_tr_norm = (x_tr_f - mean) / std
x_te_norm = (x_te_f - mean) / std

# One-hot
y_tr_oh = keras.utils.to_categorical(y_tr, N_CLASSES)
y_te_oh = keras.utils.to_categorical(y_te, N_CLASSES)

print(f"Klasy: {[class_names[k] for k in KLASY]}")
print(f"x_tr: {x_tr_norm.shape}, y_tr_oh: {y_tr_oh.shape}")
print(f"x_te: {x_te_norm.shape}, y_te_oh: {y_te_oh.shape}")
# Out:
# Klasy: ['kot', 'pies', 'zaba', 'kon']
# x_tr: (2000, 32, 32, 3), y_tr_oh: (2000, 4)
# x_te: (4000, 32, 32, 3), y_te_oh: (4000, 4)

# %%
def cnn_model(num_filters=32, dropout_conv=0.0, dropout_dense=0.5):
    """CNN architecture z PDF -- 3 bloki conv + dense + softmax.
    Mniejsza wersja niz w PDF zeby trening byl szybki.
    """
    model = keras.Sequential([
        layers.Conv2D(num_filters, 3, activation='relu', padding='same', input_shape=(32, 32, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(num_filters, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Dropout(dropout_conv),

        layers.Conv2D(2*num_filters, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(2*num_filters, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Dropout(dropout_conv),

        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout_dense),
        layers.Dense(N_CLASSES, activation='softmax')
    ])
    model.compile(optimizer=keras.optimizers.Adam(1e-3),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Baseline -- bez augmentacji
print("=== Baseline CNN (BEZ augmentacji) ===")
tf.random.set_seed(42)
model_baseline = cnn_model()
hist_baseline = model_baseline.fit(
    x_tr_norm, y_tr_oh,
    epochs=15, batch_size=64,
    validation_split=0.2,
    verbose=2
)
test_loss_b, test_acc_b = model_baseline.evaluate(x_te_norm, y_te_oh, verbose=0)
print(f"\nTest accuracy BEZ augmentacji: {test_acc_b:.4f}")
# Out:
# === Baseline CNN (BEZ augmentacji) ===
# Epoch 1/15
# /Users/macbook/miniconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 - 3s - 138ms/step - accuracy: 0.4288 - loss: 1.7438 - val_accuracy: 0.2850 - val_loss: 1.3892
# Epoch 2/15
# 25/25 - 1s - 59ms/step - accuracy: 0.5806 - loss: 1.1004 - val_accuracy: 0.2575 - val_loss: 1.7013
# Epoch 3/15
# 25/25 - 2s - 65ms/step - accuracy: 0.6787 - loss: 0.8693 - val_accuracy: 0.2550 - val_loss: 1.8743
# Epoch 4/15
# 25/25 - 2s - 65ms/step - accuracy: 0.7625 - loss: 0.6095 - val_accuracy: 0.2550 - val_loss: 1.9073
# Epoch 5/15
# 25/25 - 2s - 71ms/step - accuracy: 0.8256 - loss: 0.4451 - val_accuracy: 0.2525 - val_loss: 2.2857
# Epoch 6/15
# 25/25 - 2s - 77ms/step - accuracy: 0.8725 - loss: 0.3357 - val_accuracy: 0.2675 - val_loss: 2.0526
# Epoch 7/15
# 25/25 - 2s - 71ms/step - accuracy: 0.9100 - loss: 0.2690 - val_accuracy: 0.2575 - val_loss: 1.9631
# Epoch 8/15
# 25/25 - 2s - 72ms/step - accuracy: 0.9469 - loss: 0.1805 - val_accuracy: 0.2925 - val_loss: 1.7351
# Epoch 9/15
# 25/25 - 2s - 69ms/step - accuracy: 0.9494 - loss: 0.1589 - val_accuracy: 0.3600 - val_loss: 1.4899
# Epoch 10/15
# 25/25 - 2s - 71ms/step - accuracy: 0.9806 - loss: 0.1035 - val_accuracy: 0.3650 - val_loss: 1.9222
# Epoch 11/15
# 25/25 - 2s - 68ms/step - accuracy: 0.9850 - loss: 0.0764 - val_accuracy: 0.3550 - val_loss: 2.0878
# Epoch 12/15
# 25/25 - 2s - 71ms/step - accuracy: 0.9900 - loss: 0.0589 - val_accuracy: 0.3850 - val_loss: 1.9612
# Epoch 13/15
# 25/25 - 2s - 72ms/step - accuracy: 0.9969 - loss: 0.0405 - val_accuracy: 0.4600 - val_loss: 1.6982
# Epoch 14/15
# 25/25 - 2s - 76ms/step - accuracy: 0.9950 - loss: 0.0344 - val_accuracy: 0.4475 - val_loss: 1.5557
# Epoch 15/15
# 25/25 - 2s - 74ms/step - accuracy: 0.9987 - loss: 0.0276 - val_accuracy: 0.5225 - val_loss: 1.4369
#
# Test accuracy BEZ augmentacji: 0.5310

# %% [markdown]
# ## 1.5. CNN Z augmentacją

# %%
# Trening Z augmentacja przez ImageDataGenerator
print("=== CNN Z augmentacja ===")

datagen_train = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
)

# Podzial na train/val przed generatorem
split = int(0.8 * len(x_tr_norm))
x_t, x_v = x_tr_norm[:split], x_tr_norm[split:]
y_t, y_v = y_tr_oh[:split], y_tr_oh[split:]

tf.random.set_seed(42)
model_aug = cnn_model()
hist_aug = model_aug.fit(
    datagen_train.flow(x_t, y_t, batch_size=64),
    epochs=15,
    validation_data=(x_v, y_v),
    verbose=2
)
test_loss_a, test_acc_a = model_aug.evaluate(x_te_norm, y_te_oh, verbose=0)
print(f"\nTest accuracy Z augmentacja: {test_acc_a:.4f}")
# Out:
# === CNN Z augmentacja ===
# Epoch 1/15
# 25/25 - 4s - 146ms/step - accuracy: 0.4019 - loss: 1.9114 - val_accuracy: 0.4225 - val_loss: 1.2745
# Epoch 2/15
# 25/25 - 2s - 79ms/step - accuracy: 0.4719 - loss: 1.4599 - val_accuracy: 0.3525 - val_loss: 1.3129
# Epoch 3/15
# 25/25 - 2s - 83ms/step - accuracy: 0.5163 - loss: 1.3098 - val_accuracy: 0.3000 - val_loss: 1.4244
# Epoch 4/15
# 25/25 - 2s - 79ms/step - accuracy: 0.5519 - loss: 1.2137 - val_accuracy: 0.2950 - val_loss: 1.4208
# Epoch 5/15
# 25/25 - 2s - 73ms/step - accuracy: 0.5719 - loss: 1.0964 - val_accuracy: 0.3175 - val_loss: 1.4485
# Epoch 6/15
# 25/25 - 2s - 72ms/step - accuracy: 0.6012 - loss: 1.0585 - val_accuracy: 0.3025 - val_loss: 1.4667
# Epoch 7/15
# 25/25 - 2s - 74ms/step - accuracy: 0.6156 - loss: 1.0128 - val_accuracy: 0.4100 - val_loss: 1.3103
# Epoch 8/15
# 25/25 - 2s - 84ms/step - accuracy: 0.6219 - loss: 0.9607 - val_accuracy: 0.4900 - val_loss: 1.1750
# Epoch 9/15
# 25/25 - 2s - 77ms/step - accuracy: 0.6444 - loss: 0.8796 - val_accuracy: 0.5250 - val_loss: 1.1333
# Epoch 10/15
# 25/25 - 2s - 73ms/step - accuracy: 0.6531 - loss: 0.8830 - val_accuracy: 0.4350 - val_loss: 1.4244
# Epoch 11/15
# 25/25 - 2s - 73ms/step - accuracy: 0.6481 - loss: 0.8667 - val_accuracy: 0.4475 - val_loss: 1.3550
# Epoch 12/15
# 25/25 - 2s - 77ms/step - accuracy: 0.6794 - loss: 0.8256 - val_accuracy: 0.5650 - val_loss: 1.0932
# Epoch 13/15
# 25/25 - 2s - 79ms/step - accuracy: 0.6812 - loss: 0.7952 - val_accuracy: 0.6250 - val_loss: 1.0160
# Epoch 14/15
# 25/25 - 2s - 83ms/step - accuracy: 0.6981 - loss: 0.7724 - val_accuracy: 0.6350 - val_loss: 0.9702
# Epoch 15/15
# 25/25 - 2s - 75ms/step - accuracy: 0.7044 - loss: 0.7456 - val_accuracy: 0.6375 - val_loss: 0.9542
#
# Test accuracy Z augmentacja: 0.6050

# %%
# Porownanie krzywych uczenia
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].plot(hist_baseline.history['accuracy'], 'b-', label='Baseline train', linewidth=2)
axes[0].plot(hist_baseline.history['val_accuracy'], 'b--', label='Baseline val', linewidth=2)
axes[0].plot(hist_aug.history['accuracy'], 'r-', label='Aug train', linewidth=2)
axes[0].plot(hist_aug.history['val_accuracy'], 'r--', label='Aug val', linewidth=2)
axes[0].set_xlabel('Epoka')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Accuracy: BEZ vs Z augmentacja')
axes[0].legend()
axes[0].grid(alpha=0.3)

axes[1].plot(hist_baseline.history['loss'], 'b-', label='Baseline train', linewidth=2)
axes[1].plot(hist_baseline.history['val_loss'], 'b--', label='Baseline val', linewidth=2)
axes[1].plot(hist_aug.history['loss'], 'r-', label='Aug train', linewidth=2)
axes[1].plot(hist_aug.history['val_loss'], 'r--', label='Aug val', linewidth=2)
axes[1].set_xlabel('Epoka')
axes[1].set_ylabel('Loss')
axes[1].set_title('Loss: BEZ vs Z augmentacja')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n=== WYNIKI ===")
print(f"Baseline (bez aug): test acc = {test_acc_b:.4f}")
print(f"Z augmentacja:      test acc = {test_acc_a:.4f}")
print(f"Roznica:            {(test_acc_a - test_acc_b)*100:+.2f}%")
print("\nObserwacja: baseline OVERFITTUJE -- train acc rosnie do 100%, val acc stoi.")
print("Z augmentacja: train acc nizsze, ale val/test acc wyzsze -> lepsza generalizacja.")
# Out:
# === WYNIKI ===
# Baseline (bez aug): test acc = 0.5310
# Z augmentacja:      test acc = 0.6050
# Roznica:            +7.40%
#
# Obserwacja: baseline OVERFITTUJE -- train acc rosnie do 100%, val acc stoi.
# Z augmentacja: train acc nizsze, ale val/test acc wyzsze -> lepsza generalizacja.

# %% [markdown]
# ---
#
# ## 1.6. Hyperparameter tuning — Random Search
#
# Z PDF: *"Potraktuj zakresy transformacji geometrycznych jako hiperparametry modelu i przeprowadź ich dobór (np. przy użyciu podejścia Random Search). Jako kryterium optymalizacji wykorzystaj dokładność uzyskaną w wyniku kroswalidacji k-fold."*
#
# **Mini-demo:** sprawdzimy 4 losowe konfiguracje augmentacji i wybierzemy najlepszą po prostym holdout (zamiast pełnego KFold, żeby zmieścić się czasowo).

# %%
import time

# Przestrzen hiperparametrow
search_space = {
    'rotation_range':     [0, 10, 20, 30],
    'width_shift_range':  [0.0, 0.1, 0.2],
    'zoom_range':         [0.0, 0.1, 0.2],
}

def sample_config():
    return {k: np.random.choice(v) for k, v in search_space.items()}

N_TRIALS = 4  # zwieksz do 10+ dla rzetelnej optymalizacji

results = []
for trial in range(N_TRIALS):
    config = sample_config()
    t0 = time.time()
    print(f"\nTrial {trial+1}/{N_TRIALS}: {dict(config)}")
    
    datagen = ImageDataGenerator(
        rotation_range=int(config['rotation_range']),
        width_shift_range=float(config['width_shift_range']),
        zoom_range=float(config['zoom_range']),
        horizontal_flip=True,
    )
    
    tf.random.set_seed(42)
    model = cnn_model()
    hist = model.fit(
        datagen.flow(x_t, y_t, batch_size=64),
        epochs=8, validation_data=(x_v, y_v), verbose=0
    )
    val_acc = hist.history['val_accuracy'][-1]
    elapsed = time.time() - t0
    results.append({'config': dict(config), 'val_acc': val_acc, 'time': elapsed})
    print(f"  val_acc = {val_acc:.4f}  ({elapsed:.1f}s)")

# Najlepszy
best = max(results, key=lambda r: r['val_acc'])
print(f"\n=== Najlepsza konfiguracja ===")
print(f"Config: {best['config']}")
print(f"Val accuracy: {best['val_acc']:.4f}")
# Out:
# Trial 1/4: {'rotation_range': 0, 'width_shift_range': 0.0, 'zoom_range': 0.1}
#   val_acc = 0.3500  (17.2s)
#
# Trial 2/4: {'rotation_range': 30, 'width_shift_range': 0.0, 'zoom_range': 0.1}
#   val_acc = 0.3825  (16.7s)
#
# Trial 3/4: {'rotation_range': 30, 'width_shift_range': 0.0, 'zoom_range': 0.2}
#   val_acc = 0.5450  (16.6s)
#
# Trial 4/4: {'rotation_range': 30, 'width_shift_range': 0.1, 'zoom_range': 0.2}
#   val_acc = 0.4125  (16.7s)
#
# === Najlepsza konfiguracja ===
# Config: {'rotation_range': 30, 'width_shift_range': 0.0, 'zoom_range': 0.2}
# Val accuracy: 0.5450

# %% [markdown]
# ---
#
# # CZĘŚĆ 2 — Lab 6: Rekurencyjne Sieci Neuronowe (RNN)
#
# ## 2.1. Most: dlaczego CNN nie wystarczy?
#
# **CNN (Lab 4-5)** ekstrahuje cechy z **siatek** o stałym rozmiarze (obrazy 32x32, 224x224, ...).
#
# Co jeśli dane są **sekwencjami** o zmiennej długości?
# - **Tekst:** "Lubię koty" (3 słowa) vs "Lubię koty i psy" (5 słów)
# - **Szeregi czasowe:** kursy walut, temperatury, pomiary IoT
# - **Audio:** sygnał o długości 1s lub 10s
# - **DNA:** sekwencje nukleotydów
#
# **CNN ignoruje kolejność.** Dla sekwencji potrzebujemy sieci, która **pamięta** poprzednie elementy.
#
# ## 2.2. Architektura RNN
#
# **Kluczowa idea:** **pętla rekurencyjna**. Sieć ma **stan ukryty** $a_t$ który aktualizuje się przy każdym kroku czasowym.
#
# $$a_t = g_1(W_{aa} a_{t-1} + W_{ax} x_t + b_a)$$
# $$y_t = g_2(W_{ya} a_t + b_y)$$
#
# **Czytaj to jako:** "nowy stan = funkcja(stary stan, nowe wejście)".
#
# ### Kluczowe cechy RNN
#
# | Cecha | Co znaczy |
# |-------|-----------|
# | **Pamięć wewnętrzna** | Stan ukryty zapamiętuje kontekst |
# | **Przetwarzanie sekwencyjne** | Kolejność elementów ma znaczenie |
# | **Współdzielone wagi** | Te same $W_{aa}, W_{ax}, W_{ya}$ dla każdego kroku |
# | **Dynamiczne** | Działa na sekwencjach o dowolnej długości |
#
# **Trening: BPTT** — Backpropagation Through Time. Rozwijasz sieć w czasie (jak T kopii MLP) i propagujesz gradient wstecz przez wszystkie kroki.

# %% [markdown]
# ## 2.3. Typy struktur RNN
#
# | Typ | Schemat | Przykład zastosowania |
# |-----|---------|----------------------|
# | **One-to-one** ($T_x=T_y=1$) | x → y | Klasyczna klasyfikacja (= MLP) |
# | **One-to-many** ($T_x=1, T_y>1$) | x → y₁, y₂, ... | Generowanie muzyki, captioning obrazów |
# | **Many-to-one** ($T_x>1, T_y=1$) | x₁, x₂, ... → y | Analiza sentymentu, klasyfikacja sekwencji |
# | **Many-to-many (equal)** ($T_x=T_y$) | x_t → y_t | Tagowanie sekwencji (NER) |
# | **Many-to-many (seq2seq)** ($T_x ≠ T_y$) | x_1..T_x → y_1..T_y | Tłumaczenie maszynowe |

# %% [markdown]
# ## 2.4. Problem: Vanishing i Exploding Gradient
#
# W BPTT mnożymy gradienty przez wiele kroków czasowych. Konsekwencje:
#
# ### Vanishing gradient
# - **Przyczyna:** pochodne sigmoidy/tanh są < 1. Mnożenie ich wielokrotnie → wartość zbliża się do 0.
# - **Skutek:** sieć **zapomina** informacje z początku sekwencji.
# - **Matematyka:** jeśli $|\partial a_t / \partial a_{t-1}| < 1$, to $\prod$ → 0.
#
# ### Exploding gradient
# - **Przyczyna:** wagi duże, pochodne >> 1. Mnożenie → wybuch.
# - **Skutek:** wagi NaN, model nie zbiega.
#
# ### Rozwiązania
#
# 1. **Gradient Clipping** — ucinamy gradient powyżej progu (`clipnorm=1.0` w Keras)
# 2. **Bramki — LSTM / GRU** — kontrolowany przepływ informacji
# 3. **Regularyzacja/normalizacja** — L2, BatchNorm, LayerNorm

# %% [markdown]
# ## 2.5. LSTM — Long Short-Term Memory
#
# **LSTM** rozwiązuje vanishing gradient przez **komórkę pamięci** $C_t$ i **bramki** (gates).
#
# ### Trzy bramki
#
# 1. **Forget gate** $F_t$ — *co zapomnieć z pamięci?*
# 2. **Input gate** $I_t$ — *co nowego dodać do pamięci?*
# 3. **Output gate** $O_t$ — *co wypuścić jako wyjście?*
#
# ### Równania (6 kroków)
#
# $$F_t = \sigma(W_f \cdot [h_{t-1}, x_t] + b_f) \quad \text{forget gate}$$
# $$I_t = \sigma(W_i \cdot [h_{t-1}, x_t] + b_i) \quad \text{input gate}$$
# $$\tilde{C}_t = \tanh(W_c \cdot [h_{t-1}, x_t] + b_c) \quad \text{kandydat na pamięć}$$
# $$C_t = F_t \odot C_{t-1} + I_t \odot \tilde{C}_t \quad \text{aktualizacja pamięci}$$
# $$O_t = \sigma(W_o \cdot [h_{t-1}, x_t] + b_o) \quad \text{output gate}$$
# $$h_t = O_t \odot \tanh(C_t) \quad \text{nowy stan ukryty}$$
#
# (⊙ = iloczyn Hadamarda = mnożenie element po elemencie)
#
# **Intuicja:** komórka pamięci $C_t$ to "taśma transportowa". Forget gate decyduje co usunąć, input gate co dodać. Gradient przepływa przez tę taśmę **bez znaczących mnożeń**, więc nie zanika.
#
# ## 2.6. GRU — Gated Recurrent Unit
#
# **GRU** = uproszczona LSTM. Tylko **2 bramki** (reset, update) i brak osobnej komórki pamięci.
#
# **Plusy:** mniej parametrów, szybszy trening.
# **Minusy:** czasem gorszy w bardzo długich sekwencjach.
#
# **W praktyce:** zacznij od LSTM, spróbuj GRU jeśli wolne.

# %% [markdown]
# ---
#
# ## 2.7. DEMO LSTM — predykcja sinusoidy z szumem
#
# **Zadanie z PDF (Lab 6, Zadanie 9):** Zbuduj LSTM przewidujący sekwencję sinusoidalną z dodanym szumem.
#
# **Plan:**
# 1. Generujemy szereg czasowy: `sin(arange) + szum`
# 2. Tworzymy sekwencje wejściowe (look_back=20) i wyjścia (1 punkt)
# 3. Dzielimy na train/test
# 4. Budujemy LSTM
# 5. Trenujemy i wizualizujemy

# %%
# Krok 1: Generujemy szereg czasowy
np.random.seed(42)
N = 500
t = np.arange(N)
signal = np.sin(t * 0.3) * 0.5 + 0.5 + np.random.rand(N) * 0.2

plt.figure(figsize=(12, 3))
plt.plot(t, signal, color='#1B1E3D', linewidth=1)
plt.title("Wygenerowany szereg czasowy: sin + szum")
plt.xlabel("Krok czasowy")
plt.ylabel("Wartosc")
plt.grid(alpha=0.3)
plt.show()

print(f"Dlugosc szeregu: {N}")
print(f"Zakres: [{signal.min():.3f}, {signal.max():.3f}]")
# Out:
# Dlugosc szeregu: 500
# Zakres: [0.007, 1.189]

# %%
# Krok 2: Sekwencje (X) i targety (y) z look_back
look_back = 20

X, y = [], []
for i in range(look_back, len(signal)):
    X.append(signal[i - look_back:i])
    y.append(signal[i])

X = np.array(X).reshape(-1, look_back, 1)  # (samples, timesteps, features)
y = np.array(y)

print(f"X shape: {X.shape}  (n_sequences, look_back, n_features)")
print(f"y shape: {y.shape}")

# Podzial train/test (70/30 -- jak w PDF rysunku)
split = int(0.7 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
print(f"\nTrain: {X_train.shape[0]} sekwencji")
print(f"Test:  {X_test.shape[0]} sekwencji")
# Out:
# X shape: (480, 20, 1)  (n_sequences, look_back, n_features)
# y shape: (480,)
#
# Train: 336 sekwencji
# Test:  144 sekwencji

# %%
# Krok 3: Model LSTM
from tensorflow.keras.layers import LSTM, Dropout, Dense

tf.random.set_seed(42)
model_lstm = keras.Sequential([
    LSTM(8, input_shape=(look_back, 1)),
    Dense(1)
])
model_lstm.compile(optimizer='adam', loss='mean_squared_error')
model_lstm.summary()
# Out:
# /Users/macbook/miniconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 8)              │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 329 (1.29 KB)
#  Trainable params: 329 (1.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Krok 4: Trening
history_lstm = model_lstm.fit(
    X_train, y_train,
    epochs=20, batch_size=16,
    validation_data=(X_test, y_test),
    verbose=2
)

# Wykres loss
plt.figure(figsize=(9, 3))
plt.plot(history_lstm.history['loss'], label='train')
plt.plot(history_lstm.history['val_loss'], label='val')
plt.xlabel('Epoka')
plt.ylabel('MSE Loss')
plt.title('Krzywa uczenia LSTM')
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Epoch 1/20
# 21/21 - 1s - 40ms/step - loss: 0.3830 - val_loss: 0.2937
# Epoch 2/20
# 21/21 - 0s - 4ms/step - loss: 0.2100 - val_loss: 0.1556
# Epoch 3/20
# 21/21 - 0s - 5ms/step - loss: 0.1225 - val_loss: 0.1159
# Epoch 4/20
# 21/21 - 0s - 4ms/step - loss: 0.1058 - val_loss: 0.1082
# Epoch 5/20
# 21/21 - 0s - 3ms/step - loss: 0.0979 - val_loss: 0.1011
# Epoch 6/20
# 21/21 - 0s - 3ms/step - loss: 0.0915 - val_loss: 0.0943
# Epoch 7/20
# 21/21 - 0s - 4ms/step - loss: 0.0853 - val_loss: 0.0877
# Epoch 8/20
# 21/21 - 0s - 3ms/step - loss: 0.0791 - val_loss: 0.0812
# Epoch 9/20
# 21/21 - 0s - 4ms/step - loss: 0.0730 - val_loss: 0.0747
# Epoch 10/20
# 21/21 - 0s - 3ms/step - loss: 0.0668 - val_loss: 0.0680
# Epoch 11/20
# 21/21 - 0s - 3ms/step - loss: 0.0604 - val_loss: 0.0610
# Epoch 12/20
# 21/21 - 0s - 4ms/step - loss: 0.0537 - val_loss: 0.0536
# Epoch 13/20
# 21/21 - 0s - 5ms/step - loss: 0.0465 - val_loss: 0.0458
# Epoch 14/20
# 21/21 - 0s - 4ms/step - loss: 0.0389 - val_loss: 0.0374
# Epoch 15/20
# 21/21 - 0s - 3ms/step - loss: 0.0309 - val_loss: 0.0287
# Epoch 16/20
# 21/21 - 0s - 3ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 17/20
# 21/21 - 0s - 3ms/step - loss: 0.0151 - val_loss: 0.0128
# Epoch 18/20
# 21/21 - 0s - 3ms/step - loss: 0.0094 - val_loss: 0.0082
# Epoch 19/20
# 21/21 - 0s - 3ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 20/20
# 21/21 - 0s - 3ms/step - loss: 0.0052 - val_loss: 0.0057

# %%
# Krok 5: Predykcje
pred_test = model_lstm.predict(X_test, verbose=0).flatten()

fig, axes = plt.subplots(2, 1, figsize=(13, 7))

# Caly szereg z podzialem train/test
x_train_idx = np.arange(look_back, look_back + len(y_train))
x_test_idx = np.arange(look_back + len(y_train), look_back + len(y_train) + len(y_test))

axes[0].plot(x_train_idx, y_train, color='#1B1E3D', label='Train (rzeczywiste)', linewidth=1)
axes[0].plot(x_test_idx, y_test, color='black', label='Test (rzeczywiste)', linewidth=1)
axes[0].plot(x_test_idx, pred_test, color='#E63888', linestyle='--', label='Test (predykcja)', linewidth=1.5)
axes[0].set_title('Caly szereg z podzialem train/test')
axes[0].set_xlabel('Krok czasowy')
axes[0].set_ylabel('Wartosc')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Zoom na test
axes[1].plot(x_test_idx, y_test, color='black', label='Rzeczywiste', linewidth=1.5)
axes[1].plot(x_test_idx, pred_test, color='#E63888', linestyle='--', label='Predykcja LSTM', linewidth=1.5)
axes[1].set_title('Zoom: tylko zbior testowy')
axes[1].set_xlabel('Krok czasowy')
axes[1].set_ylabel('Wartosc')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

mse_test = ((y_test - pred_test) ** 2).mean()
print(f"\nTest MSE: {mse_test:.6f}")
print("LSTM nauczyl sie rytmu sinusoidy mimo szumu.")
# Out:
# Test MSE: 0.005716
# LSTM nauczyl sie rytmu sinusoidy mimo szumu.

# %% [markdown]
# ---
#
# # CZĘŚĆ 3 — Zadania do samodzielnego wykonania
#
# ## Zadanie A (Lab 5) — CIFAR-10 z optymalizacją augmentacji
#
# Rozszerz powyższy mini-Random Search do **pełnego pipeline'u**:
#
# 1. Użyj **wszystkich 10 klas CIFAR-10** (lub minimum 5)
# 2. Dodaj do search_space: `height_shift_range`, `brightness_range`
# 3. **K-Fold cross-validation** (k=3 lub k=5) jako kryterium oceny
# 4. Min **10 prób** Random Search
# 5. Końcowy trening z najlepszą konfiguracją na pełnym datasecie
# 6. Ewaluacja na zbiorze testowym
#
# **Bonus:** użyj `optuna` lub `hyperopt` zamiast Random Search.

# %%
# TODO Zadanie A: KFold + Random Search
# from sklearn.model_selection import KFold
#
# kf = KFold(n_splits=3, shuffle=True, random_state=42)
#
# def evaluate_config(config, X, Y, epochs=8):
#     scores = []
#     for fold_idx, (train_idx, val_idx) in enumerate(kf.split(X)):
#         datagen = ImageDataGenerator(**config)
#         model = cnn_model()
#         hist = model.fit(
#             datagen.flow(X[train_idx], Y[train_idx], batch_size=64),
#             epochs=epochs, validation_data=(X[val_idx], Y[val_idx]), verbose=0
#         )
#         scores.append(hist.history['val_accuracy'][-1])
#     return np.mean(scores)
#
# # ... petla Random Search ...

# Twoj kod tutaj:

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
import random

# 1. Gwarancja powtarzalności wyników
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# 2. Przygotowanie danych (Wczytanie i normalizacja)
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Skalowanie wartości pikseli do zakresu [0, 1]
x_train_norm = x_train.astype("float32") / 255.0
x_test_norm = x_test.astype("float32") / 255.0

# Konwersja etykiet do formatu One-Hot Encoding (10 klas)
y_train_oh = keras.utils.to_categorical(y_train, 10)
y_test_oh = keras.utils.to_categorical(y_test, 10)

print(f"Pełne dane treningowe: {x_train_norm.shape}")
print(f"Dane testowe: {x_test_norm.shape}")

# 3. Definicja architektury sieci CNN
def stworz_model_cnn():
    model = keras.Sequential([
        layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# 4. Ustawienia K-Fold i Random Search
LICZBA_PROB = 10
EPOKI_KFOLD = 4  # Zmniejszono dla szybszego przeszukiwania
SPLITS = 3
kf = KFold(n_splits=SPLITS, shuffle=True, random_state=42)

wyniki_tuning = []

print("\n" + "="*50)
print("ROZPOCZĘCIE RANDOM SEARCH Z K-FOLD CROSS VALIDATION")
print("="*50)

# 5. Główna pętla przeszukiwania (10 prób)
for i in range(LICZBA_PROB):
    # Losowanie hiperparametrów augmentacji (w tym height_shift_range i brightness_range)
    config = {
        "rotation_range": random.randint(0, 45),
        "width_shift_range": random.uniform(0.0, 0.2),
        "height_shift_range": random.uniform(0.0, 0.2),
        "zoom_range": random.uniform(0.0, 0.2),
        "brightness_range": [random.uniform(0.6, 0.9), random.uniform(1.1, 1.4)],
        "horizontal_flip": random.choice([True, False])
    }

    print(f"\n--- Próba {i+1}/{LICZBA_PROB} ---")
    print(f"Konfiguracja: {config}")

    fold_scores = []

    # Ewaluacja konfiguracji za pomocą K-Fold
    for fold_idx, (train_idx, val_idx) in enumerate(kf.split(x_train_norm)):
        # Inicjalizacja generatora i modelu
        datagen = ImageDataGenerator(fill_mode='nearest', **config)
        model = stworz_model_cnn()

        # Generator dopasowuje się tylko do danych treningowych z obecnego foldu
        datagen.fit(x_train_norm[train_idx])

        # Trening na foldzie
        hist = model.fit(
            datagen.flow(x_train_norm[train_idx], y_train_oh[train_idx], batch_size=64),
            epochs=EPOKI_KFOLD,
            validation_data=(x_train_norm[val_idx], y_train_oh[val_idx]),
            verbose=0  # Wyłączamy szczegółowe logi w trakcie K-Folda
        )

        # Pobieramy dokładność walidacyjną z ostatniej epoki
        val_acc = hist.history['val_accuracy'][-1]
        fold_scores.append(val_acc)
        print(f"  Fold {fold_idx+1}/{SPLITS} - val_accuracy: {val_acc:.4f}")

    srednia_dokladnosc = np.mean(fold_scores)
    print(f"Średnia dokładność walidacyjna (K-Fold): {srednia_dokladnosc:.4f}")

    wyniki_tuning.append({
        "config": config,
        "score": srednia_dokladnosc
    })

# Wybór najlepszej konfiguracji
najlepsza_proba = max(wyniki_tuning, key=lambda x: x["score"])
najlepsza_konfiguracja = najlepsza_proba["config"]

print("\n" + "="*50)
print("PODSUMOWANIE RANDOM SEARCH")
print("="*50)
print(f"Najlepszy wynik K-Fold: {najlepsza_proba['score']:.4f}")
print("Najlepsza konfiguracja augmentacji:")
for k, v in najlepsza_konfiguracja.items():
    print(f" - {k}: {v}")

# 6. Końcowy trening z najlepszą konfiguracją na pełnym datasecie (50k próbek)
print("\n=== Trenowanie ostatecznego modelu na PEŁNYM zbiorze treningowym ===")
final_datagen = ImageDataGenerator(fill_mode='nearest', **najlepsza_konfiguracja)
final_datagen.fit(x_train_norm)

final_model = stworz_model_cnn()
history_final = final_model.fit(
    final_datagen.flow(x_train_norm, y_train_oh, batch_size=64),
    epochs=15, # Trenujemy dłużej, aby model osiągnął pełen potencjał
    verbose=1
)

# 7. Ewaluacja na ukrytym zbiorze testowym
print("\n=== Ostateczna Ewaluacja na Zbiorze Testowym ===")
test_loss, test_acc = final_model.evaluate(x_test_norm, y_test_oh, verbose=1)
print(f"\nOSTATECZNY WYNIK: Test Accuracy = {test_acc:.4f}")
# Out:
# Pełne dane treningowe: (50000, 32, 32, 3)
# Dane testowe: (10000, 32, 32, 3)
#
# ==================================================
# ROZPOCZĘCIE RANDOM SEARCH Z K-FOLD CROSS VALIDATION
# ==================================================
#
# --- Próba 1/10 ---
# Konfiguracja: {'rotation_range': 40, 'width_shift_range': 0.022266213633136078, 'height_shift_range': 0.1483100999519666, 'zoom_range': 0.04897837076069525, 'brightness_range': [0.6418613785575431, 1.1307485528514523], 'horizontal_flip': True}
# /Users/konrad/miniforge3/envs/tf/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Fold 1/3 - val_accuracy: 0.0986
#   Fold 2/3 - val_accuracy: 0.1039
#   Fold 3/3 - val_accuracy: 0.1038
# Średnia dokładność walidacyjna (K-Fold): 0.1021
#
# --- Próba 2/10 ---
# Konfiguracja: {'rotation_range': 1, 'width_shift_range': 0.030429861023473826, 'height_shift_range': 0.19394324352587872, 'zoom_range': 0.004426177123095965, 'brightness_range': [0.8916997814974341, 1.1846343612727415], 'horizontal_flip': True}
#   Fold 1/3 - val_accuracy: 0.0985
#   Fold 2/3 - val_accuracy: 0.0995
#   Fold 3/3 - val_accuracy: 0.1024
# Średnia dokładność walidacyjna (K-Fold): 0.1001
#
# --- Próba 3/10 ---
# Konfiguracja: {'rotation_range': 38, 'width_shift_range': 0.036273097514261755, 'height_shift_range': 0.0850489097091854, 'zoom_range': 0.17862351040135827, 'brightness_range': [0.8061482153122808, 1.2874274816011546], 'horizontal_flip': False}
#   Fold 1/3 - val_accuracy: 0.0985
#   Fold 2/3 - val_accuracy: 0.1028
#   Fold 3/3 - val_accuracy: 0.1086
# Średnia dokładność walidacyjna (K-Fold): 0.1033
#
# --- Próba 4/10 ---
# Konfiguracja: {'rotation_range': 45, 'width_shift_range': 0.00011922403154303042, 'height_shift_range': 0.15871879900884697, 'zoom_range': 0.1009022173284519, 'brightness_range': [0.6323402602118319, 1.143306664934405], 'horizontal_flip': True}
#   Fold 1/3 - val_accuracy: 0.1079
#   Fold 2/3 - val_accuracy: 0.1001
#   Fold 3/3 - val_accuracy: 0.1262
# Średnia dokładność walidacyjna (K-Fold): 0.1114
#
# --- Próba 5/10 ---
# Konfiguracja: {'rotation_range': 34, 'width_shift_range': 0.1719058577094535, 'height_shift_range': 0.15587014019867362, 'zoom_range': 0.09569527387664334, 'brightness_range': [0.6972935544906919, 1.3261254957228652], 'horizontal_flip': True}
#   Fold 1/3 - val_accuracy: 0.1033
#   Fold 2/3 - val_accuracy: 0.1001
#   Fold 3/3 - val_accuracy: 0.1074
# Średnia dokładność walidacyjna (K-Fold): 0.1036
#
# --- Próba 6/10 ---
# Konfiguracja: {'rotation_range': 3, 'width_shift_range': 0.13028014141283367, 'height_shift_range': 0.14031213984251428, 'zoom_range': 0.15050854854641016, 'brightness_range': [0.8808627007011065, 1.3933330669585837], 'horizontal_flip': False}
#   Fold 1/3 - val_accuracy: 0.1131
#   Fold 2/3 - val_accuracy: 0.1015
#   Fold 3/3 - val_accuracy: 0.1031
# Średnia dokładność walidacyjna (K-Fold): 0.1059
#
# --- Próba 7/10 ---
# Konfiguracja: {'rotation_range': 10, 'width_shift_range': 0.16504732973992942, 'height_shift_range': 0.04596235881406241, 'zoom_range': 0.144262117740874, 'brightness_range': [0.616620648983005, 1.2603661363762937], 'horizontal_flip': False}
#   Fold 1/3 - val_accuracy: 0.1170
#   Fold 2/3 - val_accuracy: 0.1040
#   Fold 3/3 - val_accuracy: 0.1038
# Średnia dokładność walidacyjna (K-Fold): 0.1083
#
# --- Próba 8/10 ---
# Konfiguracja: {'rotation_range': 28, 'width_shift_range': 0.15129743490301759, 'height_shift_range': 0.09708269476891018, 'zoom_range': 0.08941417915370518, 'brightness_range': [0.6613720594054001, 1.3434045661809337], 'horizontal_flip': True}
#   Fold 1/3 - val_accuracy: 0.1006
#   Fold 2/3 - val_accuracy: 0.0999
#   Fold 3/3 - val_accuracy: 0.1022
# Średnia dokładność walidacyjna (K-Fold): 0.1009
#
# --- Próba 9/10 ---
# Konfiguracja: {'rotation_range': 41, 'width_shift_range': 0.07365386495036567, 'height_shift_range': 0.13220375092880104, 'zoom_range': 0.1501812634850429, 'brightness_range': [0.853926216043319, 1.259617279490632], 'horizontal_flip': True}
#   Fold 1/3 - val_accuracy: 0.0984
#   Fold 2/3 - val_accuracy: 0.1064
#   Fold 3/3 - val_accuracy: 0.1090
# Średnia dokładność walidacyjna (K-Fold): 0.1046
#
# --- Próba 10/10 ---
# Konfiguracja: {'rotation_range': 9, 'width_shift_range': 0.19574913301822883, 'height_shift_range': 0.19878958824355464, 'zoom_range': 0.18163115648784955, 'brightness_range': [0.6771705446657524, 1.193033445251097], 'horizontal_flip': False}
#   Fold 1/3 - val_accuracy: 0.1278
#   Fold 2/3 - val_accuracy: 0.1181
#   Fold 3/3 - val_accuracy: 0.1049
# Średnia dokładność walidacyjna (K-Fold): 0.1169
#
# ==================================================
# PODSUMOWANIE RANDOM SEARCH
# ==================================================
# Najlepszy wynik K-Fold: 0.1169
# Najlepsza konfiguracja augmentacji:
#  - rotation_range: 9
#  - width_shift_range: 0.19574913301822883
#  - height_shift_range: 0.19878958824355464
#  - zoom_range: 0.18163115648784955
#  - brightness_range: [0.6771705446657524, 1.193033445251097]
#  - horizontal_flip: False
#
# === Trenowanie ostatecznego modelu na PEŁNYM zbiorze treningowym ===
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.1048 - loss: 2.5494
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1040 - loss: 2.4155
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1029 - loss: 2.3567
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.1032 - loss: 2.3283
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1027 - loss: 2.3138
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1033 - loss: 2.3081
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.1039 - loss: 2.3054
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1055 - loss: 2.3039
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1063 - loss: 2.3022
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.1034 - loss: 2.3013
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1061 - loss: 2.3020
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.1047 - loss: 2.3007
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1035 - loss: 2.3004
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.1074 - loss: 2.2980
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.1056 - loss: 2.2978
#
# === Ostateczna Ewaluacja na Zbiorze Testowym ===
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.1000 - loss: 2.7943
#
# OSTATECZNY WYNIK: Test Accuracy = 0.1000

# %% [markdown]
# ## Zadanie B (Lab 6) — predykcja PM-10 dla Krakowa
#
# Z PDF: *"Na podstawie danych Głównego Inspektoratu Środowiska ze stacji pomiarowej Kraków, ul. Złoty Róg, opracuj model do przewidywania stężenia pyłów zawieszonych PM-10. Przeprowadź badania różnych architektur modeli sekwencyjnych."*
#
# **Plan:**
# 1. Wczytaj dane (CSV z Teams) — kolumna z wartościami PM-10
# 2. Wyczyść (NaN), znormalizuj (`MinMaxScaler` 0-1)
# 3. Stwórz sekwencje: look_back=24 (1 dzień przy danych godzinowych) lub look_back=7 (1 tydzień przy dziennych)
# 4. Podział train/test (80/20)
# 5. **Trzy modele do porównania:**
#    - SimpleRNN (vanilla)
#    - LSTM
#    - GRU
# 6. Wykres porównawczy: real vs predicted dla każdego modelu
# 7. **Wniosek:** który model najlepszy i dlaczego?

# %%
# TODO Zadanie B: PM-10 prediction
# import pandas as pd
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.layers import SimpleRNN, LSTM, GRU
# 
# # 1. Wczytaj dane
# df = pd.read_csv('PM10_kierunkowo.csv', sep=';', encoding='ISO-8859-1')
# # ... preprocessing ...
# 
# # 2. Sekwencje
# look_back = 24
# X, y = [], []
# for i in range(look_back, len(scaled)):
#     X.append(scaled[i-look_back:i, 0])
#     y.append(scaled[i, 0])
# 
# # 3. Porownanie 3 modeli
# models = {
#     'SimpleRNN': keras.Sequential([SimpleRNN(32, input_shape=(look_back, 1)), Dense(1)]),
#     'LSTM':      keras.Sequential([LSTM(32, input_shape=(look_back, 1)), Dense(1)]),
#     'GRU':       keras.Sequential([GRU(32, input_shape=(look_back, 1)), Dense(1)]),
# }
# 
# # Trenuj kazdy, porownaj wyniki

# Twoj kod tutaj:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense, Dropout, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

tf.random.set_seed(42)
np.random.seed(42)

df = pd.read_csv('PM10_kierunkowo.csv', sep=';')
df['data'] = pd.to_datetime(df['data'])
print(df.head())
print(df.dtypes)

pm10_col = 'pm10'

series = df[pm10_col].values.astype('float32')
pm10_series = pd.Series(series).interpolate(method='linear').bfill().values

look_back = 7
title_suffix = "Kraków - Złoty Róg (dane dobowe)"

# 1. Wizualizacja surowego szeregu
plt.figure(figsize=(13, 3))
plt.plot(df['data'], pm10_series, color='#1B1E3D', linewidth=0.8)
plt.title(f"Szereg PM-10 - {title_suffix}")
plt.xlabel("Data")
plt.ylabel("PM-10 [ug/m3]")
plt.axhline(50,  color='orange', linestyle='--', alpha=0.7, label='Norma dobowa UE (50 ug/m3)')
plt.axhline(100, color='red',    linestyle='--', alpha=0.7, label='Poziom informowania (100 ug/m3)')
plt.legend(fontsize=9)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 2. Normalizacja MinMaxScaler -> zakres [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(pm10_series.reshape(-1, 1))   # (N, 1)

# 3. Tworzenie sekwencji (look_back, 1) -> target
def make_sequences(data, lb):
    X, y = [], []
    for i in range(lb, len(data)):
        X.append(data[i - lb:i, 0])
        y.append(data[i, 0])
    return np.array(X).reshape(-1, lb, 1), np.array(y)

X, y = make_sequences(scaled, look_back)

# Podzial 80% train / 20% test (zachowanie kolejnosci czasowej!)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

test_dates = df['data'].iloc[-len(y_test):].values

# 4. Definicje trzech modeli sekwencyjnych
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense, Dropout

def build_rnn(cell_type, units=64):
    cell = {'SimpleRNN': SimpleRNN, 'LSTM': LSTM, 'GRU': GRU}[cell_type]
    model = keras.Sequential([
        Input(shape=(look_back, 1)),
        cell(units, return_sequences=True),
        Dropout(0.2),
        cell(units // 2),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(1),
    ])
    model.compile(optimizer=keras.optimizers.Adam(1e-3), loss='mse', metrics=['mae'])
    return model

# 5. Trening i ocena wszystkich trzech modeli
models_def  = ['SimpleRNN', 'LSTM', 'GRU']
histories   = {}
predictions = {}
test_metrics = {}

callbacks_rnn = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                       patience=4, verbose=0),
]

for name in models_def:
    print(f"\\n{'='*50}\\nTrening: {name} (units=64, look_back={look_back}h)\\n{'='*50}")
    tf.random.set_seed(42)
    model = build_rnn(name, units=64)

    hist = model.fit(
        X_train, y_train,
        epochs=40, batch_size=32,
        validation_split=0.15,
        callbacks=callbacks_rnn,
        verbose=2,
        shuffle=True
    )
    histories[name] = hist.history

    # Predykcje na zbiorze testowym (odwrotna normalizacja do ug/m3)
    y_pred_scaled = model.predict(X_test, verbose=0).flatten()
    y_pred = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
    y_real = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
    predictions[name] = {'pred': y_pred, 'real': y_real}

    rmse = np.sqrt(mean_squared_error(y_real, y_pred))
    mae  = mean_absolute_error(y_real, y_pred)
    mape = np.mean(np.abs((y_real - y_pred) / (y_real + 1e-6))) * 100
    test_metrics[name] = {'RMSE': rmse, 'MAE': mae, 'MAPE': mape}
    print(f"  Test -> RMSE={rmse:.2f} ug/m3 | MAE={mae:.2f} ug/m3 | MAPE={mape:.1f}%")

# 6. Wizualizacja wynikow
clr = {'SimpleRNN': '#E63888', 'LSTM': '#1B1E3D', 'GRU': '#2196F3'}

fig, axes = plt.subplots(4, 1, figsize=(14, 16))
fig.suptitle(f"Zadanie B - Predykcja PM-10\\n{title_suffix}", fontsize=13)

# Krzywe uczenia (val_loss)
for name in models_def:
    axes[0].plot(histories[name]['val_loss'], color=clr[name], label=f"{name}", lw=2)
axes[0].set_title("Krzywe uczenia - val_loss (MSE)")
axes[0].set_xlabel("Epoka"); axes[0].set_ylabel("MSE (znorm.)")
axes[0].legend(); axes[0].grid(alpha=0.3)

# Predykcje vs rzeczywistosc (kazdy model w osobnym subplot)
zoom = 50
real = list(predictions.values())[0]['real']

for idx, name in enumerate(models_def, 1):
    pred = predictions[name]['pred']
    m = test_metrics[name]

    # Rysowanie z użyciem wyciętych dat dla osi X
    axes[idx].plot(test_dates[-zoom:], real[-zoom:], color='black',   lw=1.5, label='Rzeczywiste')
    axes[idx].plot(test_dates[-zoom:], pred[-zoom:], color=clr[name], lw=1.5, linestyle='--', label=f'{name}')

    axes[idx].axhline(50,  color='orange', linestyle=':', alpha=0.6)
    axes[idx].axhline(100, color='red',    linestyle=':', alpha=0.6)
    axes[idx].set_title(f"{name}  |  RMSE={m['RMSE']:.2f}  MAE={m['MAE']:.2f}  MAPE={m['MAPE']:.1f}%")
    axes[idx].set_xlabel("Data")
    axes[idx].set_ylabel("PM-10 [ug/m3]")
    axes[idx].legend(fontsize=9)
    axes[idx].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# Porownanie metryk (bar chart)
fig2, axes2 = plt.subplots(1, 3, figsize=(14, 4))
for ax, metric in zip(axes2, ['RMSE', 'MAE', 'MAPE']):
    vals = [test_metrics[n][metric] for n in models_def]
    bars = ax.bar(models_def, vals, color=[clr[n] for n in models_def], edgecolor='black')
    ax.bar_label(bars, fmt='%.2f', padding=3, fontsize=10)
    ax.set_title(f"{metric} na zbiorze testowym")
    ax.set_ylabel(metric + (" [ug/m3]" if metric != 'MAPE' else " [%]"))
    ax.grid(axis='y', alpha=0.3)
plt.suptitle("Porownanie metryk - SimpleRNN vs LSTM vs GRU", fontsize=13, y=1.03)
plt.tight_layout(); plt.show()

# 7. Wnioski
best_model = min(test_metrics, key=lambda n: test_metrics[n]['RMSE'])
print("\\n=== WNIOSKI ===")
print("Porownanie modeli sekwencyjnych dla predykcji PM-10:")
for n in models_def:
    m = test_metrics[n]
    print(f"  {n:10s}: RMSE={m['RMSE']:.2f} ug/m3, MAE={m['MAE']:.2f} ug/m3, MAPE={m['MAPE']:.1f}%")
print(f"Najlepszy model wg RMSE: {best_model}")
# Out:
#         data         kod_stanowiska   pm10
# 0 2021-01-01  MpKrakZloRog-PM10-24g  50.27
# 1 2021-01-02  MpKrakZloRog-PM10-24g  56.21
# 2 2021-01-03  MpKrakZloRog-PM10-24g  50.60
# 3 2021-01-04  MpKrakZloRog-PM10-24g  53.28
# 4 2021-01-05  MpKrakZloRog-PM10-24g  21.53
# data              datetime64[us]
# kod_stanowiska               str
# pm10                     float64
# dtype: object
# \n==================================================\nTrening: SimpleRNN (units=64, look_back=7h)\n==================================================
# Epoch 1/40
# 31/31 - 4s - 126ms/step - loss: 0.0611 - mae: 0.1826 - val_loss: 0.0346 - val_mae: 0.1512 - learning_rate: 0.0010
# Epoch 2/40
# 31/31 - 2s - 58ms/step - loss: 0.0387 - mae: 0.1429 - val_loss: 0.0131 - val_mae: 0.0849 - learning_rate: 0.0010
# Epoch 3/40
# 31/31 - 2s - 57ms/step - loss: 0.0323 - mae: 0.1326 - val_loss: 0.0130 - val_mae: 0.0827 - learning_rate: 0.0010
# Epoch 4/40
# 31/31 - 2s - 57ms/step - loss: 0.0333 - mae: 0.1362 - val_loss: 0.0129 - val_mae: 0.0832 - learning_rate: 0.0010
# Epoch 5/40
# 31/31 - 2s - 59ms/step - loss: 0.0439 - mae: 0.1618 - val_loss: 0.0156 - val_mae: 0.0837 - learning_rate: 0.0010
# Epoch 6/40
# 31/31 - 2s - 61ms/step - loss: 0.0308 - mae: 0.1347 - val_loss: 0.0204 - val_mae: 0.1179 - learning_rate: 0.0010
# Epoch 7/40
# 31/31 - 2s - 63ms/step - loss: 0.0200 - mae: 0.1076 - val_loss: 0.0157 - val_mae: 0.0849 - learning_rate: 0.0010
# Epoch 8/40
# 31/31 - 2s - 56ms/step - loss: 0.0185 - mae: 0.1034 - val_loss: 0.0151 - val_mae: 0.0921 - learning_rate: 5.0000e-04
# Epoch 9/40
# 31/31 - 2s - 56ms/step - loss: 0.0172 - mae: 0.0983 - val_loss: 0.0152 - val_mae: 0.0880 - learning_rate: 5.0000e-04
# Epoch 10/40
# 31/31 - 2s - 56ms/step - loss: 0.0161 - mae: 0.0926 - val_loss: 0.0151 - val_mae: 0.0906 - learning_rate: 5.0000e-04
# Epoch 11/40
# 31/31 - 2s - 56ms/step - loss: 0.0143 - mae: 0.0861 - val_loss: 0.0148 - val_mae: 0.0882 - learning_rate: 5.0000e-04
# Epoch 12/40
# 31/31 - 2s - 56ms/step - loss: 0.0134 - mae: 0.0826 - val_loss: 0.0151 - val_mae: 0.0936 - learning_rate: 2.5000e-04
# Epoch 13/40
# 31/31 - 2s - 56ms/step - loss: 0.0126 - mae: 0.0796 - val_loss: 0.0146 - val_mae: 0.0885 - learning_rate: 2.5000e-04
# Epoch 14/40
# 31/31 - 2s - 58ms/step - loss: 0.0129 - mae: 0.0795 - val_loss: 0.0147 - val_mae: 0.0905 - learning_rate: 2.5000e-04
# Epoch 15/40
# 31/31 - 2s - 56ms/step - loss: 0.0123 - mae: 0.0787 - val_loss: 0.0146 - val_mae: 0.0908 - learning_rate: 2.5000e-04
# Epoch 16/40
# 31/31 - 2s - 56ms/step - loss: 0.0125 - mae: 0.0792 - val_loss: 0.0144 - val_mae: 0.0895 - learning_rate: 1.2500e-04
# Epoch 17/40
# 31/31 - 2s - 56ms/step - loss: 0.0122 - mae: 0.0777 - val_loss: 0.0142 - val_mae: 0.0867 - learning_rate: 1.2500e-04
# Epoch 18/40
# 31/31 - 2s - 56ms/step - loss: 0.0125 - mae: 0.0780 - val_loss: 0.0141 - val_mae: 0.0869 - learning_rate: 1.2500e-04
# Epoch 19/40
# 31/31 - 2s - 55ms/step - loss: 0.0115 - mae: 0.0742 - val_loss: 0.0140 - val_mae: 0.0858 - learning_rate: 1.2500e-04
# Epoch 20/40
# 31/31 - 2s - 56ms/step - loss: 0.0114 - mae: 0.0757 - val_loss: 0.0140 - val_mae: 0.0856 - learning_rate: 6.2500e-05
# Epoch 21/40
# 31/31 - 2s - 59ms/step - loss: 0.0110 - mae: 0.0740 - val_loss: 0.0139 - val_mae: 0.0858 - learning_rate: 6.2500e-05
# Epoch 22/40
# 31/31 - 2s - 59ms/step - loss: 0.0117 - mae: 0.0745 - val_loss: 0.0139 - val_mae: 0.0854 - learning_rate: 6.2500e-05
# Epoch 23/40
# 31/31 - 2s - 59ms/step - loss: 0.0115 - mae: 0.0748 - val_loss: 0.0139 - val_mae: 0.0856 - learning_rate: 6.2500e-05
# Epoch 24/40
# 31/31 - 2s - 58ms/step - loss: 0.0117 - mae: 0.0758 - val_loss: 0.0139 - val_mae: 0.0848 - learning_rate: 3.1250e-05
# Epoch 25/40
# 31/31 - 2s - 59ms/step - loss: 0.0119 - mae: 0.0765 - val_loss: 0.0139 - val_mae: 0.0858 - learning_rate: 3.1250e-05
# Epoch 26/40
# 31/31 - 2s - 58ms/step - loss: 0.0113 - mae: 0.0739 - val_loss: 0.0139 - val_mae: 0.0856 - learning_rate: 3.1250e-05
# Epoch 27/40
# 31/31 - 2s - 59ms/step - loss: 0.0114 - mae: 0.0753 - val_loss: 0.0139 - val_mae: 0.0852 - learning_rate: 3.1250e-05
# Epoch 28/40
# 31/31 - 2s - 58ms/step - loss: 0.0116 - mae: 0.0745 - val_loss: 0.0139 - val_mae: 0.0850 - learning_rate: 1.5625e-05
# Epoch 29/40
# 31/31 - 2s - 56ms/step - loss: 0.0115 - mae: 0.0744 - val_loss: 0.0139 - val_mae: 0.0853 - learning_rate: 1.5625e-05
# Epoch 30/40
# 31/31 - 2s - 55ms/step - loss: 0.0109 - mae: 0.0732 - val_loss: 0.0138 - val_mae: 0.0853 - learning_rate: 1.5625e-05
# Epoch 31/40
# 31/31 - 2s - 55ms/step - loss: 0.0113 - mae: 0.0742 - val_loss: 0.0138 - val_mae: 0.0853 - learning_rate: 1.5625e-05
# Epoch 32/40
# 31/31 - 2s - 56ms/step - loss: 0.0113 - mae: 0.0754 - val_loss: 0.0138 - val_mae: 0.0854 - learning_rate: 7.8125e-06
# Epoch 33/40
# 31/31 - 2s - 55ms/step - loss: 0.0112 - mae: 0.0744 - val_loss: 0.0138 - val_mae: 0.0855 - learning_rate: 7.8125e-06
# Epoch 34/40
# 31/31 - 2s - 55ms/step - loss: 0.0114 - mae: 0.0746 - val_loss: 0.0138 - val_mae: 0.0856 - learning_rate: 7.8125e-06
# Epoch 35/40
# 31/31 - 2s - 55ms/step - loss: 0.0115 - mae: 0.0749 - val_loss: 0.0138 - val_mae: 0.0851 - learning_rate: 7.8125e-06
# Epoch 36/40
# 31/31 - 2s - 56ms/step - loss: 0.0114 - mae: 0.0749 - val_loss: 0.0138 - val_mae: 0.0851 - learning_rate: 3.9063e-06
# Epoch 37/40
# 31/31 - 2s - 56ms/step - loss: 0.0114 - mae: 0.0741 - val_loss: 0.0138 - val_mae: 0.0851 - learning_rate: 3.9063e-06
# Epoch 38/40
# 31/31 - 2s - 55ms/step - loss: 0.0109 - mae: 0.0734 - val_loss: 0.0138 - val_mae: 0.0854 - learning_rate: 3.9063e-06
# Epoch 39/40
# 31/31 - 2s - 55ms/step - loss: 0.0112 - mae: 0.0737 - val_loss: 0.0138 - val_mae: 0.0855 - learning_rate: 3.9063e-06
# Epoch 40/40
# 31/31 - 2s - 55ms/step - loss: 0.0113 - mae: 0.0743 - val_loss: 0.0138 - val_mae: 0.0854 - learning_rate: 1.9531e-06
#   Test -> RMSE=11.23 ug/m3 | MAE=7.41 ug/m3 | MAPE=38.7%
# \n==================================================\nTrening: LSTM (units=64, look_back=7h)\n==================================================
# Epoch 1/40
# 31/31 - 2s - 67ms/step - loss: 0.0209 - mae: 0.1050 - val_loss: 0.0180 - val_mae: 0.0916 - learning_rate: 0.0010
# Epoch 2/40
# 31/31 - 0s - 15ms/step - loss: 0.0142 - mae: 0.0840 - val_loss: 0.0175 - val_mae: 0.0952 - learning_rate: 0.0010
# Epoch 3/40
# 31/31 - 0s - 13ms/step - loss: 0.0140 - mae: 0.0823 - val_loss: 0.0176 - val_mae: 0.0970 - learning_rate: 0.0010
# Epoch 4/40
# 31/31 - 0s - 13ms/step - loss: 0.0133 - mae: 0.0797 - val_loss: 0.0175 - val_mae: 0.0980 - learning_rate: 0.0010
# Epoch 5/40
# 31/31 - 0s - 14ms/step - loss: 0.0130 - mae: 0.0790 - val_loss: 0.0173 - val_mae: 0.0953 - learning_rate: 5.0000e-04
# Epoch 6/40
# 31/31 - 0s - 13ms/step - loss: 0.0131 - mae: 0.0794 - val_loss: 0.0172 - val_mae: 0.0949 - learning_rate: 5.0000e-04
# Epoch 7/40
# 31/31 - 0s - 13ms/step - loss: 0.0131 - mae: 0.0790 - val_loss: 0.0170 - val_mae: 0.0948 - learning_rate: 5.0000e-04
# Epoch 8/40
# 31/31 - 0s - 13ms/step - loss: 0.0126 - mae: 0.0782 - val_loss: 0.0168 - val_mae: 0.0944 - learning_rate: 5.0000e-04
# Epoch 9/40
# 31/31 - 0s - 13ms/step - loss: 0.0126 - mae: 0.0777 - val_loss: 0.0168 - val_mae: 0.0929 - learning_rate: 2.5000e-04
# Epoch 10/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0772 - val_loss: 0.0166 - val_mae: 0.0938 - learning_rate: 2.5000e-04
# Epoch 11/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0767 - val_loss: 0.0165 - val_mae: 0.0922 - learning_rate: 2.5000e-04
# Epoch 12/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0765 - val_loss: 0.0164 - val_mae: 0.0921 - learning_rate: 2.5000e-04
# Epoch 13/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0768 - val_loss: 0.0163 - val_mae: 0.0926 - learning_rate: 1.2500e-04
# Epoch 14/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0774 - val_loss: 0.0162 - val_mae: 0.0917 - learning_rate: 1.2500e-04
# Epoch 15/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0763 - val_loss: 0.0162 - val_mae: 0.0920 - learning_rate: 1.2500e-04
# Epoch 16/40
# 31/31 - 0s - 13ms/step - loss: 0.0121 - mae: 0.0758 - val_loss: 0.0161 - val_mae: 0.0915 - learning_rate: 1.2500e-04
# Epoch 17/40
# 31/31 - 0s - 13ms/step - loss: 0.0120 - mae: 0.0754 - val_loss: 0.0161 - val_mae: 0.0916 - learning_rate: 6.2500e-05
# Epoch 18/40
# 31/31 - 0s - 13ms/step - loss: 0.0124 - mae: 0.0761 - val_loss: 0.0160 - val_mae: 0.0921 - learning_rate: 6.2500e-05
# Epoch 19/40
# 31/31 - 0s - 13ms/step - loss: 0.0122 - mae: 0.0763 - val_loss: 0.0160 - val_mae: 0.0918 - learning_rate: 6.2500e-05
# Epoch 20/40
# 31/31 - 0s - 13ms/step - loss: 0.0121 - mae: 0.0759 - val_loss: 0.0160 - val_mae: 0.0915 - learning_rate: 6.2500e-05
# Epoch 21/40
# 31/31 - 0s - 13ms/step - loss: 0.0121 - mae: 0.0759 - val_loss: 0.0160 - val_mae: 0.0911 - learning_rate: 3.1250e-05
# Epoch 22/40
# 31/31 - 0s - 13ms/step - loss: 0.0123 - mae: 0.0761 - val_loss: 0.0159 - val_mae: 0.0913 - learning_rate: 3.1250e-05
# Epoch 23/40
# 31/31 - 0s - 13ms/step - loss: 0.0123 - mae: 0.0761 - val_loss: 0.0159 - val_mae: 0.0913 - learning_rate: 3.1250e-05
# Epoch 24/40
# 31/31 - 0s - 13ms/step - loss: 0.0122 - mae: 0.0759 - val_loss: 0.0159 - val_mae: 0.0912 - learning_rate: 3.1250e-05
# Epoch 25/40
# 31/31 - 0s - 13ms/step - loss: 0.0118 - mae: 0.0748 - val_loss: 0.0159 - val_mae: 0.0913 - learning_rate: 1.5625e-05
# Epoch 26/40
# 31/31 - 0s - 13ms/step - loss: 0.0123 - mae: 0.0769 - val_loss: 0.0159 - val_mae: 0.0912 - learning_rate: 1.5625e-05
# Epoch 27/40
# 31/31 - 0s - 13ms/step - loss: 0.0120 - mae: 0.0753 - val_loss: 0.0159 - val_mae: 0.0912 - learning_rate: 1.5625e-05
# Epoch 28/40
# 31/31 - 0s - 13ms/step - loss: 0.0122 - mae: 0.0759 - val_loss: 0.0159 - val_mae: 0.0910 - learning_rate: 1.5625e-05
# Epoch 29/40
# 31/31 - 0s - 13ms/step - loss: 0.0119 - mae: 0.0755 - val_loss: 0.0158 - val_mae: 0.0910 - learning_rate: 7.8125e-06
# Epoch 30/40
# 31/31 - 0s - 13ms/step - loss: 0.0119 - mae: 0.0751 - val_loss: 0.0158 - val_mae: 0.0911 - learning_rate: 7.8125e-06
# Epoch 31/40
# 31/31 - 0s - 13ms/step - loss: 0.0119 - mae: 0.0757 - val_loss: 0.0158 - val_mae: 0.0911 - learning_rate: 7.8125e-06
# Epoch 32/40
# 31/31 - 0s - 13ms/step - loss: 0.0117 - mae: 0.0745 - val_loss: 0.0158 - val_mae: 0.0911 - learning_rate: 7.8125e-06
# Epoch 33/40
# 31/31 - 0s - 13ms/step - loss: 0.0122 - mae: 0.0761 - val_loss: 0.0158 - val_mae: 0.0911 - learning_rate: 3.9063e-06
# Epoch 34/40
# 31/31 - 0s - 13ms/step - loss: 0.0122 - mae: 0.0763 - val_loss: 0.0158 - val_mae: 0.0910 - learning_rate: 3.9063e-06
# Epoch 35/40
# 31/31 - 0s - 13ms/step - loss: 0.0121 - mae: 0.0752 - val_loss: 0.0158 - val_mae: 0.0910 - learning_rate: 3.9063e-06
# Epoch 36/40
# 31/31 - 0s - 13ms/step - loss: 0.0122 - mae: 0.0755 - val_loss: 0.0158 - val_mae: 0.0910 - learning_rate: 3.9063e-06
# Epoch 37/40
# 31/31 - 0s - 13ms/step - loss: 0.0121 - mae: 0.0749 - val_loss: 0.0158 - val_mae: 0.0910 - learning_rate: 1.9531e-06
# Epoch 38/40
# 31/31 - 0s - 13ms/step - loss: 0.0120 - mae: 0.0759 - val_loss: 0.0158 - val_mae: 0.0910 - learning_rate: 1.9531e-06
# Epoch 39/40
# 31/31 - 0s - 13ms/step - loss: 0.0119 - mae: 0.0752 - val_loss: 0.0158 - val_mae: 0.0909 - learning_rate: 1.9531e-06
# Epoch 40/40
# 31/31 - 0s - 13ms/step - loss: 0.0120 - mae: 0.0758 - val_loss: 0.0158 - val_mae: 0.0909 - learning_rate: 1.9531e-06
#   Test -> RMSE=12.10 ug/m3 | MAE=8.20 ug/m3 | MAPE=43.5%
# \n==================================================\nTrening: GRU (units=64, look_back=7h)\n==================================================
# Epoch 1/40
# 31/31 - 2s - 61ms/step - loss: 0.0168 - mae: 0.0924 - val_loss: 0.0150 - val_mae: 0.0870 - learning_rate: 0.0010
# Epoch 2/40
# 31/31 - 0s - 14ms/step - loss: 0.0121 - mae: 0.0769 - val_loss: 0.0145 - val_mae: 0.0876 - learning_rate: 0.0010
# Epoch 3/40
# 31/31 - 0s - 13ms/step - loss: 0.0117 - mae: 0.0741 - val_loss: 0.0142 - val_mae: 0.0877 - learning_rate: 0.0010
# Epoch 4/40
# 31/31 - 0s - 13ms/step - loss: 0.0111 - mae: 0.0717 - val_loss: 0.0134 - val_mae: 0.0843 - learning_rate: 0.0010
# Epoch 5/40
# 31/31 - 0s - 13ms/step - loss: 0.0107 - mae: 0.0705 - val_loss: 0.0131 - val_mae: 0.0811 - learning_rate: 5.0000e-04
# Epoch 6/40
# 31/31 - 0s - 13ms/step - loss: 0.0103 - mae: 0.0696 - val_loss: 0.0127 - val_mae: 0.0800 - learning_rate: 5.0000e-04
# Epoch 7/40
# 31/31 - 0s - 13ms/step - loss: 0.0101 - mae: 0.0681 - val_loss: 0.0123 - val_mae: 0.0785 - learning_rate: 5.0000e-04
# Epoch 8/40
# 31/31 - 0s - 12ms/step - loss: 0.0101 - mae: 0.0687 - val_loss: 0.0120 - val_mae: 0.0781 - learning_rate: 5.0000e-04
# Epoch 9/40
# 31/31 - 0s - 13ms/step - loss: 0.0103 - mae: 0.0681 - val_loss: 0.0117 - val_mae: 0.0776 - learning_rate: 5.0000e-04
# Epoch 10/40
# 31/31 - 0s - 13ms/step - loss: 0.0096 - mae: 0.0669 - val_loss: 0.0115 - val_mae: 0.0769 - learning_rate: 5.0000e-04
# Epoch 11/40
# 31/31 - 0s - 13ms/step - loss: 0.0098 - mae: 0.0669 - val_loss: 0.0112 - val_mae: 0.0754 - learning_rate: 5.0000e-04
# Epoch 12/40
# 31/31 - 0s - 13ms/step - loss: 0.0091 - mae: 0.0646 - val_loss: 0.0109 - val_mae: 0.0752 - learning_rate: 5.0000e-04
# Epoch 13/40
# 31/31 - 0s - 13ms/step - loss: 0.0098 - mae: 0.0667 - val_loss: 0.0109 - val_mae: 0.0765 - learning_rate: 5.0000e-04
# Epoch 14/40
# 31/31 - 0s - 12ms/step - loss: 0.0092 - mae: 0.0654 - val_loss: 0.0107 - val_mae: 0.0747 - learning_rate: 5.0000e-04
# Epoch 15/40
# 31/31 - 0s - 12ms/step - loss: 0.0090 - mae: 0.0646 - val_loss: 0.0105 - val_mae: 0.0738 - learning_rate: 5.0000e-04
# Epoch 16/40
# 31/31 - 0s - 12ms/step - loss: 0.0085 - mae: 0.0626 - val_loss: 0.0104 - val_mae: 0.0741 - learning_rate: 5.0000e-04
# Epoch 17/40
# 31/31 - 0s - 12ms/step - loss: 0.0087 - mae: 0.0634 - val_loss: 0.0103 - val_mae: 0.0731 - learning_rate: 5.0000e-04
# Epoch 18/40
# 31/31 - 0s - 13ms/step - loss: 0.0086 - mae: 0.0627 - val_loss: 0.0102 - val_mae: 0.0726 - learning_rate: 5.0000e-04
# Epoch 19/40
# 31/31 - 0s - 14ms/step - loss: 0.0088 - mae: 0.0637 - val_loss: 0.0103 - val_mae: 0.0732 - learning_rate: 5.0000e-04
# Epoch 20/40
# 31/31 - 0s - 13ms/step - loss: 0.0088 - mae: 0.0629 - val_loss: 0.0103 - val_mae: 0.0729 - learning_rate: 5.0000e-04
# Epoch 21/40
# 31/31 - 0s - 13ms/step - loss: 0.0084 - mae: 0.0630 - val_loss: 0.0103 - val_mae: 0.0729 - learning_rate: 5.0000e-04
# Epoch 22/40
# 31/31 - 0s - 12ms/step - loss: 0.0088 - mae: 0.0635 - val_loss: 0.0103 - val_mae: 0.0720 - learning_rate: 2.5000e-04
# Epoch 23/40
# 31/31 - 0s - 13ms/step - loss: 0.0084 - mae: 0.0620 - val_loss: 0.0103 - val_mae: 0.0723 - learning_rate: 2.5000e-04
# Epoch 24/40
# 31/31 - 0s - 12ms/step - loss: 0.0088 - mae: 0.0634 - val_loss: 0.0103 - val_mae: 0.0723 - learning_rate: 2.5000e-04
# Epoch 25/40
# 31/31 - 0s - 12ms/step - loss: 0.0088 - mae: 0.0627 - val_loss: 0.0104 - val_mae: 0.0725 - learning_rate: 2.5000e-04
# Epoch 26/40
# 31/31 - 0s - 12ms/step - loss: 0.0084 - mae: 0.0621 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 1.2500e-04
# Epoch 27/40
# 31/31 - 0s - 13ms/step - loss: 0.0087 - mae: 0.0625 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 1.2500e-04
# Epoch 28/40
# 31/31 - 0s - 12ms/step - loss: 0.0084 - mae: 0.0620 - val_loss: 0.0104 - val_mae: 0.0722 - learning_rate: 1.2500e-04
# Epoch 29/40
# 31/31 - 0s - 13ms/step - loss: 0.0086 - mae: 0.0627 - val_loss: 0.0104 - val_mae: 0.0721 - learning_rate: 1.2500e-04
# Epoch 30/40
# 31/31 - 0s - 12ms/step - loss: 0.0088 - mae: 0.0630 - val_loss: 0.0104 - val_mae: 0.0721 - learning_rate: 6.2500e-05
# Epoch 31/40
# 31/31 - 0s - 12ms/step - loss: 0.0086 - mae: 0.0628 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 6.2500e-05
# Epoch 32/40
# 31/31 - 0s - 12ms/step - loss: 0.0089 - mae: 0.0639 - val_loss: 0.0104 - val_mae: 0.0722 - learning_rate: 6.2500e-05
# Epoch 33/40
# 31/31 - 0s - 12ms/step - loss: 0.0087 - mae: 0.0624 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 6.2500e-05
# Epoch 34/40
# 31/31 - 0s - 12ms/step - loss: 0.0085 - mae: 0.0619 - val_loss: 0.0104 - val_mae: 0.0724 - learning_rate: 3.1250e-05
# Epoch 35/40
# 31/31 - 0s - 12ms/step - loss: 0.0086 - mae: 0.0628 - val_loss: 0.0104 - val_mae: 0.0724 - learning_rate: 3.1250e-05
# Epoch 36/40
# 31/31 - 0s - 12ms/step - loss: 0.0089 - mae: 0.0636 - val_loss: 0.0104 - val_mae: 0.0724 - learning_rate: 3.1250e-05
# Epoch 37/40
# 31/31 - 0s - 13ms/step - loss: 0.0086 - mae: 0.0629 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 3.1250e-05
# Epoch 38/40
# 31/31 - 0s - 12ms/step - loss: 0.0084 - mae: 0.0616 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 1.5625e-05
# Epoch 39/40
# 31/31 - 0s - 12ms/step - loss: 0.0083 - mae: 0.0614 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 1.5625e-05
# Epoch 40/40
# 31/31 - 0s - 12ms/step - loss: 0.0086 - mae: 0.0626 - val_loss: 0.0104 - val_mae: 0.0723 - learning_rate: 1.5625e-05
#   Test -> RMSE=10.25 ug/m3 | MAE=6.47 ug/m3 | MAPE=34.0%
# \n=== WNIOSKI ===
# Porownanie modeli sekwencyjnych dla predykcji PM-10:
#   SimpleRNN : RMSE=11.23 ug/m3, MAE=7.41 ug/m3, MAPE=38.7%
#   LSTM      : RMSE=12.10 ug/m3, MAE=8.20 ug/m3, MAPE=43.5%
#   GRU       : RMSE=10.25 ug/m3, MAE=6.47 ug/m3, MAPE=34.0%
# Najlepszy model wg RMSE: GRU

# %% [markdown]
# ### Obserwacje
# **Najlepszy model**: GRU (RMSE=10.25 µg/m³, MAE=6.47 µg/m³, MAPE=34.0%) — osiągnął najniższe błędy we wszystkich trzech metrykach.
#
# **Nieoczekiwany wynik**: LSTM wypadł najgorzej (RMSE=12.10, MAPE=43.5%), gorszy nawet od prostego SimpleRNN. Przy stosunkowo krótkich sekwencjach (look_back=7 dni) i niewielkim zbiorze danych dobowych mechanizm bramek LSTM może być nadmiarowo złożony, co prowadzi do gorszej generalizacji.
#
# **GRU jako złoty środek** — mniej parametrów niż LSTM, ale skuteczniejsze bramki niż SimpleRNN. Krzywa val_loss GRU (niebieski) systematycznie maleje przez wszystkie 40 epok i jako jedyna osiąga wartości poniżej 0.011, podczas gdy LSTM i SimpleRNN stabilizują się powyżej 0.015.
#
# **Wszystkie modele zaniżają wartości szczytowe** — widoczne na wykresach predykcji: rzeczywiste skoki PM-10 (np. ~57 µg/m³ na początku grudnia) są przez każdy model wygładzane. To typowe zjawisko przy regresji MSE, która karze za duże błędy i "ciągnie" predykcje ku średniej.
#
# **Żaden model nie przekroczył normy dobowej UE (50 µg/m³)** w swoich predykcjach, mimo że dane rzeczywiste kilkukrotnie ją przekroczyły — co jest istotnym ograniczeniem praktycznym przy zastosowaniach ostrzegawczych.
#
# **Potencjalne kierunki poprawy**: dłuższy look_back (np. 14–30 dni), dodanie cech egzogenicznych (temperatura, prędkość wiatru, ciśnienie), zastosowanie modeli wielokrokowych (seq2seq) lub podejść opartych na Transformerach.

# %% [markdown]
# ---
#
# ## Sprawdź, co umiesz — pytania kontrolne
#
# **Część Lab 5:**
# 1. **Po co augmentacja danych?** (3 korzyści)
# 2. **Czym różni się on-the-fly od pre-processing augmentacji?**
# 3. **Jakie są 3 grupy technik augmentacji?**
# 4. **Co robi `ImageDataGenerator.flow()`?**
# 5. **Co znaczy overfitting i jak augmentacja temu zapobiega?**
#
# **Część Lab 6:**
# 6. **Dlaczego CNN nie nadaje się do szeregów czasowych?**
# 7. **Co to jest stan ukryty $a_t$ w RNN?**
# 8. **Wymień 3 typy struktur RNN i ich zastosowania.**
# 9. **Co to vanishing gradient i jak LSTM go rozwiązuje?**
# 10. **Jakie są 3 bramki w LSTM i co każda robi?**
#
# ---
#
# ## Jedno zdanie do zapamiętania
#
# > **Augmentacja to sztuczne tworzenie wariacji obrazów, żeby CNN nauczyła się generalizować. RNN/LSTM to sieci z pętlą rekurencyjną, które pamiętają kontekst — używamy ich do sekwencji (tekst, szeregi czasowe, audio). LSTM rozwiązuje vanishing gradient przez bramki kontrolujące przepływ pamięci.**
#
# ## Co dalej?
#
# - **Transformery** — wyparły LSTM w NLP (Attention is All You Need)
# - **CNN+RNN combo** — np. video classification
# - **Transfer learning** — pretrenowane modele (ResNet, EfficientNet) zamiast trenowania od zera
# - **Augmentacja audio/tekstu** — SpecAugment, back-translation
